# %% [markdown]
# # Image Resize
#
# # Syntax :
#
# * # cv2.resize(src, dsize[, dst[, fx[, fy[, interpolation]]]])

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from IPython import display

# %%
img = Image.open('../1_Basic/3_Access_Pixel,row,colum_and_croping/pic/an1.jpg')
# display.Image("../1_Basic/3_Access_Pixel,row,colum_and_croping/pic/an1.jpg")
plt.figure(figsize=(10,10))
plt.imshow(img)
