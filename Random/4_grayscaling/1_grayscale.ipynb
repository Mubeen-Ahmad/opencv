# %% [markdown]
# # Grayscaling is the process of converting an image from other color spaces
#    * # e.g. RGB, CMYK, HSV, etc. to shades of gray. It varies between complete black and complete white.
#
# # Importance of grayscaling
#
#    * ### Dimension reduction:
#        * #### For example, In RGB images there are three color channels and has three dimensions while grayscale images are single-dimensional.
#    * ### Reduces model complexity:
#        * #### Consider training neural article on RGB images of 10x10x3 pixel. The input layer will have 300 input nodes. On the other hand, the same neural network will need only 100 input nodes for grayscale images.
#    * ### For other algorithms to work:
#         * #### Many algorithms are customized to work only on grayscale images e.g. Canny edge detection function pre-implemented in OpenCV library works on Grayscale images only.

# %% [markdown]
# # cv2.cvtColor() function
#
#     cvtColor(src, code[, dst[, dstCn]]) -> dst

# %%
import cv2,numpy as np
import matplotlib.pyplot as plt

def convert(img):
    plt.figure(figsize=(10,10))
    return cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img = cv2.imread("../2_Image_Blur/ron.jpg",)
plt.imshow(convert(img))

# %%
new = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(convert(new))

# %% [markdown]
# # Other method with imread
#
# ## imread(img,cv2.IMREAD_GRAYSCALE)
#
# ### Also used 0 instead of cv2.IMREAD_GRAYSCALE

# %%
img = cv2.imread("../2_Image_Blur/ron.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(convert(img))
