# %%
import cv2,matplotlib.pyplot as plt

def convert(img):
    plt.figure(figsize=(10,10))
    return cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img1 = cv2.imread("./bal.jpg")
img2 = cv2.imread("./f1.jpg")
img2 = cv2.resize(img2,(img1.shape[1],img1.shape[0]))

# %%
b,g,r = cv2.split(convert(img1))
gray1 = cv2.cvtColor(b,cv2.COLOR_BGR2RGB)

# %%
b,g,r = cv2.split(convert(img2))
gray2 = cv2.cvtColor(b,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(gray1)

# %%
plt.imshow(gray2)

# %% [markdown]
# # And
#
# # cv2.bitwise_and(source1, source2, destination, mask)
#
#     source1: First Input Image array(Single-channel, 8-bit or floating-point)
#     source2: Second Input Image array(Single-channel, 8-bit or floating-point)
#     dest: Output array (Similar to the dimensions and type of Input image array)
#     mask: Operation mask, Input / output 8-bit single-channel mask

# %%
new = cv2.bitwise_and(gray1,gray2)
plt.imshow(new)

# %% [markdown]
# # or
#
# # cv2.bitwise_or(source1, source2, destination, mask)
#
#     source1: First Input Image array(Single-channel, 8-bit or floating-point)
#     source2: Second Input Image array(Single-channel, 8-bit or floating-point)
#     dest: Output array (Similar to the dimensions and type of Input image array)
#     mask: Operation mask, Input / output 8-bit single-channel mask

# %%
new = cv2.bitwise_or(img1,img2)
plt.imshow(new)

# %% [markdown]
# # not
#
# # cv2.bitwise_not(source1, source2, destination, mask)
#
#     source1: First Input Image array(Single-channel, 8-bit or floating-point)
#     source2: Second Input Image array(Single-channel, 8-bit or floating-point)
#     dest: Output array (Similar to the dimensions and type of Input image array)
#     mask: Operation mask, Input / output 8-bit single-channel mask

# %%
new = cv2.bitwise_not(img1,img2)
plt.imshow(new)

# %% [markdown]
# # xor
#
# # cv2.bitwise_xor(source1, source2, destination, mask)
#
#     source1: First Input Image array(Single-channel, 8-bit or floating-point)
#     source2: Second Input Image array(Single-channel, 8-bit or floating-point)
#     dest: Output array (Similar to the dimensions and type of Input image array)
#     mask: Operation mask, Input / output 8-bit single-channel mask

# %%
new = cv2.bitwise_xor(img1,gray1)
plt.imshow(new)
