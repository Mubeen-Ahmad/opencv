# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.zeros((512, 512, 3), dtype = "uint8")
plt.figure(figsize=(10,10))

line1 = cv2.line(img,(250,50),(480,450),(0,255,0),4)
line2 = cv2.line(lin311,(250,50),(50,450),(0,255,0),4)
line3 = cv2.line(img,(50,450),(480,450),(0,255,0),4)
plt.imshow(line3)
