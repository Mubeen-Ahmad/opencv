# %% [markdown]
# # Line
# ## Syntax :
# * ## cv2.line(image, start_point, end_point, color, thickness)
# ## Understand Line
#
# # (start points) , (end points)
# # (x1,y1) , (x2,y2)
# # x1 --> start Vertical point
# # y1 --> start Horizontal point
#
# # x2 --> End Vertical point
# # y2 --> End Horizontal point

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def value(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10,10))
    return image

# %%
img = cv2.imread("../3_Access_Pixel,row,colum_and_croping/pic/bg.jpg")
plt.imshow(value(img))

# %% [markdown]
# # Draw Vertical line
#
# # x1 = 0
# # y1 = 0
#
# # x2 = 0
# # y2 = 600

# %%
x1 = 0
y1 = 0

x2 = 0
y2 = 600 

line = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)

# %% [markdown]
# # Change x1 (horizontal start point)

# %%
x1 = 600
y1 = 0

x2 = 0
y2 = 600 

line = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)

# %% [markdown]
# # Change y1 (vertical start point)

# %%
x1 = 600
y1 = 100

x2 = 0
y2 = 600 

line = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)

# %% [markdown]
# # Change y1 100 to 400

# %%
x1 = 600
y1 = 400

x2 = 0
y2 = 600 

line = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)

# %% [markdown]
# # Draw Horizontal line
# # Change y1 400 to 600

# %%
x1 = 600
y1 = 600

x2 = 0
y2 = 600 

line = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)

# %%
x1 = 0
y1 = 600

x2 = 1550
y2 = 600 

line = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)

# %% [markdown]
# # Draw a cross

# %%
x1 = 0
y1 = 0

x2 = 1550
y2 = 800

line1 = cv2.line(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line1)

# %%
x1 = 1550
y1 = 0

x2 = 0
y2 = 790

plt.figure(figsize=(10,10))
line2 = cv2.line(line1,(x1,y1),(x2,y2),255,15)
plt.imshow(line2)

# %%
x1 = 0
y1 = 600

x2 = 1550
y2 = 600 

line = cv2.arrowedLine(value(img),(x1,y1),(x2,y2),255,15)
plt.imshow(line)
