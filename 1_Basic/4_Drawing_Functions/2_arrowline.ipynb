# %% [markdown]
# # cv2.arrowedLine(image, start_point, end_point, color, thickness, line_type, shift, tipLength)
#
# # it is same as line

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

def value(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10,10))
    return image

# %%
img = cv2.imread("../3_Access_Pixel,row,colum_and_croping/pic/bg.jpg")
plt.imshow(value(img))

# %%
x1 = 0
y1 = 0

x2 = 600
y2 = 270 

line = cv2.arrowedLine(value(img),(x1,y1),(x2,y2),(0,255,0),15)
plt.imshow(line)
